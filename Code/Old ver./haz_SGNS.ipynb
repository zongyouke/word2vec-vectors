# %%
import torch
import torch.nn as nn
#import torch.nn.functional as F
import torch.optim as optim
#import torchvision.models as models
#from torch.profiler import profile, record_function, ProfilerActivity
#import torch.autograd.profiler as profiler

import time
import math
import random

import numpy as np
from tqdm import tqdm # adding a process bar

# check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("GPU")
else:
    device = torch.device("cpu")
    print("CPU")

torch.manual_seed(1)
# Out:
# CPU

# %%
WINDOW_SIZE = 2

# subject to later update
EMBEDDING_DIM = 100 

# negative-to-positive ratio
k = 4 

# constant for subsampling
t = 1e-5

# generate sentence heads and endings according to window size
sent_head = [f'*d{i}*' for i in range(1, WINDOW_SIZE+1)]
sent_ending = [f'*f{i}'for i in range(1, WINDOW_SIZE+1)]

# initialize vocab set
vocab = set(sent_head[0:WINDOW_SIZE] + sent_ending[0:WINDOW_SIZE])

# %%
def create_examples(tok_sents, w2i, i2w, word2nbocc):

    pos_examples = []

    # neg_examples = []
    
    ls_neg_example = [] # list of array to be concatenated

    ls_all_tokens2i = [w2i[tok] for tok in vocab]
    set_ls_all_tokens2i = set(ls_all_tokens2i)

    # consumed time for each step 
    t_pos = 0
    t_neg = 0
    t_remove_tokens = 0
    t_unigram = 0
    t_neg_array = 0
    t_neg_append = 0

    # sum of all occurences
    Z = sum(word2nbocc.values())

    # probability of each word unigram: method 2
    p_dict = {key: (val/Z)**0.75 for key, val in word2nbocc.items()}

    processed_token = 0

    for sent in tok_sents:
        sent2i = [w2i[tok] for tok in sent]

        #print(len(sent2i))

        # create positive and negative examples around each word of a sentence
        for i in range(WINDOW_SIZE, len(sent2i)-WINDOW_SIZE):
            processed_token +=1

            for j in range(1, WINDOW_SIZE+1):
                t_create_start = time.time()

                target = sent2i[i]

                t_create_pos_start = time.time()

                # positive examples
                pos_examples.append((target, sent2i[i-j], 1))
                pos_examples.append((target, sent2i[i+j], 1))


                t_create_neg_start = time.time()
                t_pos += (t_create_neg_start - t_create_pos_start)

                # negative examples

                t_remove_token_start = time.time()

                ## remove tokens in current sentence
                ls_complementary_tokens = list(set_ls_all_tokens2i - set(sent2i))

                ## unigram distribution according to Word2Vec
                t_unigram_start = time.time()

                #method 1 (works alone without the above line that generates p_dict):
                #p = np.array([(word2nbocc[i2w[token]]/Z)**0.75 for token in ls_complementary_tokens])

                #method 2:
                p = np.array([p_dict[i2w[token]] for token in ls_complementary_tokens])
                
                # normalize probabilities to make sum = 1
                p = p / p.sum()

                t_neg_array_start = time.time()
                # create pool with 2k negative words
                neg_words = np.random.choice(ls_complementary_tokens, size=2*k, p=p)
                # neg_example = [(target, neg, 0) for neg in neg_words]
                # neg_examples += neg_example

                t_neg_append_start = time.time()
                ls_neg_example.append(
                    np.array([(target, neg, 0) for neg in neg_words])
                )

                t_create_neg_end = time.time()
                
                
                # calculation of consumed time for each step 
                t_neg += (t_create_neg_end - t_create_neg_start)
                t_remove_tokens += (t_unigram_start - t_remove_token_start)
                t_unigram += (t_neg_array_start - t_unigram_start)
                t_neg_array += (t_neg_append_start- t_neg_array_start)
                t_neg_append += (t_create_neg_end - t_neg_append_start)

    print(f"Pos ex creation finished in {t_pos} second(s)")
    print(f"Neg ex creation finished in {t_neg} second(s)")

    print()
    print(f"Remove tokens finished in {t_remove_tokens} second(s)")
    print(f"Unigram finished in {t_unigram} second(s)")
    print(f"Array finished in {t_neg_array} second(s)")
    print(f"Append finished in {t_neg_append} second(s)")

    print()
    print(f"Processed {processed_token} tokens.")


    pos_examples = np.array(pos_examples)
    #print(pos_examples)

    #print()
    #print(ls_neg_example)

    # concatenate neg examples so that it has the same shape as pos examples
    neg_examples = np.vstack(ls_neg_example)
    #print(neg_examples)

    return pos_examples, neg_examples

# %%
def subsampling(tok_sents, word2nbocc):

    subsampled_sents = []
    sum_occ = sum(word2nbocc.values())
    nb_subsamples = 0

    t_sub_start = time.time()

    for tok_sent in tok_sents:
        sample = []

        # ignore tokens that have a greater probability than randomly chosen one
        # probability is calculated based on the equation proposed by word2vec
        for i in range(WINDOW_SIZE, len(tok_sent)-WINDOW_SIZE):
            rel_freq = word2nbocc[tok_sent[i]]/sum_occ
            prob = 1 - math.sqrt(t / rel_freq)
            if (random.random() > prob): 
                sample.append(tok_sent[i])

        # add sentence head and ending markers
        nb_subsamples += len(sample)
        sample = sent_head + sample + sent_ending
        subsampled_sents.append(sample)

    t_sub_end = time.time()
    print(f"Subsampling finished in {t_sub_end - t_sub_start} second(s)")

    return subsampled_sents, nb_subsamples

# %% [markdown]
# ## Lecture du corpus

# %%
i2w = []
w2i = {}
word2nbocc = {}
tok_sents = []
subsampled_sents = []
 
t0 = time.time()
data_file_path = "train_3000.txt"
#data_file_path = "EP.tcs.melt.utf8.split-aa"
    

nb_tokens = 0

t_data = 0
t_token = 0
t_vocab = 0
t_dict = 0


with open(data_file_path,'r',encoding='utf-8') as f:
    for line in f:

        t_token_start = time.time()

        tok_sent = []
        line = line.split()

        for elem in line:
            s = elem.split("/",1)[0]
            if len(s) > 0:  # avoid empty string 
                tok_sent.append(s)

        tok_sents.append(tok_sent)
        nb_tokens += len(tok_sent)

        t_vocab_start = time.time()
        t_token += t_vocab_start - t_token_start

        vocab = vocab.union(tok_sent)

        t_dict_start = time.time()
        t_vocab += t_dict_start - t_vocab_start

        # generate occurrence dictionary
        for tok in tok_sent:
            if tok not in word2nbocc.keys():
                word2nbocc[tok] = 1
            else:
                word2nbocc[tok] += 1

        #t_dict_end = time.time()
        #t_dict += t_dict_end - t_dict_start

#print(f"Tokenization finished in {t_token} second(s)")
#print(f"Vocab finished in {t_vocab} second(s)")
#print(f"Dictionary finished in {t_dict} second(s)")

vocab_size = len(vocab)
#EMBEDDING_DIM = len(vocab)   
i2w = list(vocab)
w2i = {w:i for i,w in enumerate(i2w)}

#subsampling
subsampled_sents, nb_subsamples = subsampling(tok_sents, word2nbocc)

#generate pos and neg examples
pos_examples, neg_examples = create_examples(subsampled_sents, w2i, i2w,  word2nbocc)

print()
print(f"{data_file_path} has {nb_tokens} tokens, {nb_subsamples} subsampled tokens.")
print(f"{data_file_path} has {len(pos_examples)} positive examples and {len(neg_examples)} negative examples.")
t1 = time.time()

print()
print(f"Preprocessing finished in {t1-t0} second(s)")
# Out:
# Subsampling finished in 0.026306629180908203 second(s)
# Pos ex creation finished in 0.020664691925048828 second(s)
# Neg ex creation finished in 73.98966479301453 second(s)
#
# Remove tokens finished in 5.711493015289307 second(s)
# Unigram finished in 51.483500719070435 second(s)
# Array finished in 16.217626333236694 second(s)
# Append finished in 0.5727570056915283 second(s)
#
# Processed 8619 tokens.
#
# train_3000.txt has 53862 tokens, 8619 subsampled tokens.
# train_3000.txt has 34476 positive examples and 137904 negative examples.
#
# Preprocessing finished in 74.91899228096008 second(s)

# %%
class SGNS(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(SGNS, self).__init__()
        self.net = nn.Sequential(
            nn.Embedding(vocab_size, EMBEDDING_DIM),            
            nn.Embedding(vocab_size, EMBEDDING_DIM)            
        )        
    
    def forward(self, target_words, inputs_context):
        # mat_word = self.net[0](inputs_word)
        # mat_context = self.net[1](inputs_context)
        # pred = torch.bmm(mat_word, mat_context) 
        #score = F.sigmoid(pred, dim=1)
        # score = torch.sigmoid(pred) #

        target_embeddings = self.net[0](target_words)       # [batch_size, emb_size]
        context_embeddings = self.net[1](inputs_context) # [batch_size, emb_size]

        mul = target_embeddings * context_embeddings   # [batch_size, emb_size]
        scores = torch.sum(mul, dim = 1)   # batch_size

        return scores
        

losses = []
#loss_function = nn.NLLLoss() # calc and grab the loss value

loss_function = nn.BCEWithLogitsLoss(reduction = 'sum')

model = SGNS(len(vocab), EMBEDDING_DIM).to(device) # add the selected device to the model

"""step lr"""
#lrn_rate = 100 # start very big
#optimizer = optim.SGD(model.parameters(), lr=lrn_rate)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.99) # gamma=0.99

"""ASGD lr"""
# optimizer = torch.optim.ASGD(model.parameters(), lr=lrn_rate, lambd=0.0001, alpha=0.75, t0=1000000.0, weight_decay=0) # mplements Averaged Stochastic Gradient Descent.

"""lambda lr"""
# optimizer = torch.optim.SGD(model.parameters(), lr=100)
# lambda1 = lambda epoch: 0.65 ** epoch
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)

"""Multiplicative LR"""
#optimizer = torch.optim.SGD(model.parameters(), lr=100)
#lmbda = lambda epoch: 0.65 ** epoch
#scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lmbda)

"""Cyclic LR"""
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=0.001 , max_lr=0.10)

# %% [markdown]
# ## Training

# %%
from random import shuffle

#def train(pos_examples, neg_examples):

BATCH_SIZE =8
NB_EPOCHS=5 

print(f"Nb of examples = {len(pos_examples) + len(neg_examples)}")

# concatenate all examples
examples = np.vstack([pos_examples, neg_examples])

losses = []
loss = 0
# creates once at the beginning of training
# scaler = torch.cuda.amp.GradScaler()

# time consumed for each step 
t_score = 0
t_loss = 0
t_backward = 0
t_totalloss = 0

t2 = time.time()

# for epoch in range(NB_EPOCHS):
for i in tqdm(range(NB_EPOCHS)): # processing bar applied here
    
    shuffle(examples)
    total_loss = 0
    batch_head = 0
    
    # forward propagation with mini-batch 

    while batch_head < len(examples):
        t_batch_start = time.time()

        with profiler.record_function("load input batch"):
          batch = examples[batch_head:batch_head + BATCH_SIZE]        
          # batch_gpu = [torch.as_tensor(t, device=torch.device('cuda')) for t in batch]        
          (targets, contexts, labels) = zip(*batch)

          #torch.cuda.empty_cache()
          #torch.cuda.synchronize()
          
          targets = torch.tensor(targets)
          contexts = torch.tensor(contexts)
          labels = torch.tensor(labels) # TAnh ajoute
          #targets = torch.tensor(targets, device=torch.device('cuda'))
          #contexts = torch.tensor(contexts, device=torch.device('cuda'))
          #labels = torch.tensor(labels, device=torch.device('cuda'))

        with profiler.record_function("zero out"):
          for param in model.parameters(): # to zero out gradients
              param.grad = None
        
        t_score_start = time.time()
        with profiler.record_function("forward - score"):
          # Run the forward propagation and getting scores for each mini-batch 
          score = model(targets, contexts)
        
        t_score_end = time.time()
        #print(f"Score calculation finished in {t_score_end - t_score_start} second(s)")
            
        # Compute loss function
        t_loss_start = time.time()

        with profiler.record_function("forward - loss"):
          loss = loss_function(score, labels.float())
        # with torch.cuda.amp.autocast():
        #    loss = loss_function(score, batch_contexts)
        
        t_loss_end = time.time()
        #print(f"Loss calculation finished in {t_loss_end - t_loss_start} second(s)")

        # Do backward propagation and update gradients
        t_backward_start = time.time()
        with profiler.record_function("backward"):
          loss.backward() # apply this loss backwards through the network's parameters

        # Scales the loss, and calls backwards()
        # to create scaled gradients
        # scaler.scale(loss).backward()
              
        with profiler.record_function("backward - optimizer"):
          optimizer.step() # attempt to optimize weights to account for loss/gradients
        
        # Unscales gradients and calls
        # or skips optimizer().step()
        # scaler.step(optimizer)

        # Updates the scale for next iteration
        # scaler.update()

        with profiler.record_function("backward - scheduler"):
          scheduler.step() # adjust LR
        # current_lr = scheduler.get_last_lr()
        t_backward_end = time.time()

        print(f"Back propagation finished in {t_backward_end - t_backward_start} second(s)")

        # Get the Python number from a 1-element Tensor by calling tensor.item()
        
        # Calculate total loss for each epoch
        t_totalloss_start = time.time()
        
        with profiler.record_function("total loss"):
          total_loss += loss.item()          

        t_totalloss_end = time.time()    

        print(f"Total loss calculation finished in {t_totalloss_end - t_totalloss_start} second(s)")

        batch_head += 1
        #print(f"batch no.{i} : loss = {loss.item()}")
        t_batch_end = time.time()
        #print(f"Batch {i} finished in {t_batch_end - t_batch_start} second(s)")

    # print('epoch : {} \tLoss : {}'.format(epoch, total_loss))
    losses.append(total_loss)     
    
    #print(f"Score calculation finished in {t_batch_end - t_batch_start} second(s)")

print()
print(losses)  # The loss decreased every iteration over the training data!

t3 = time.time()

print(f"Training of {data_file_path} finished in {t3-t2} second(s)")
# Out:
# Nb of examples = 172380
#   0%|          | 0/5 [00:00<?, ?it/s]
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Back propagation finished in 0.008534908294677734 second(s)
# Total loss calculation finished in 5.245208740234375e-05 second(s)
# Back propagation finished in 0.0035097599029541016 second(s)
# Total loss calculation finished in 0.00026345252990722656 second(s)
# Back propagation finished in 0.0035326480865478516 second(s)
# Total loss calculation finished in 0.0007059574127197266 second(s)
# Back propagation finished in 0.004691600799560547 second(s)
# Total loss calculation finished in 5.555152893066406e-05 second(s)
# Back propagation finished in 0.005053997039794922 second(s)
# Total loss calculation finished in 5.245208740234375e-05 second(s)
# Back propagation finished in 0.0037763118743896484 second(s)
# Total loss calculation finished in 0.0003523826599121094 second(s)
# Back propagation finished in 0.003740549087524414 second(s)
# Total loss calculation finished in 0.0006878376007080078 second(s)
# Back propagation finished in 0.0036330223083496094 second(s)
# Total loss calculation finished in 0.0007281303405761719 second(s)
# Back propagation finished in 0.003667116165161133 second(s)
# Total loss calculation finished in 0.0006690025329589844 second(s)
# Back propagation finished in 0.003582477569580078 second(s)
# Total loss calculation finished in 0.0006237030029296875 second(s)
# Back propagation finished in 0.0036001205444335938 second(s)
# Total loss calculation finished in 0.0006511211395263672 second(s)
# Back propagation finished in 0.004086017608642578 second(s)
# Total loss calculation finished in 0.0007233619689941406 second(s)
# Back propagation finished in 0.003632783889770508 second(s)
# Total loss calculation finished in 0.0006718635559082031 second(s)
# Back propagation finished in 0.0035409927368164062 second(s)
# Total loss calculation finished in 0.0005881786346435547 second(s)
# Back propagation finished in 0.003864765167236328 second(s)
# Total loss calculation finished in 0.0003943443298339844 second(s)
# Back propagation finished in 0.0035190582275390625 second(s)
# Total loss calculation finished in 0.0006959438323974609 second(s)
# Back propagation finished in 0.0036401748657226562 second(s)
# Total loss calculation finished in 0.0006837844848632812 second(s)
# Back propagation finished in 0.0036373138427734375 second(s)
# Total loss calculation finished in 0.0006725788116455078 second(s)
# Back propagation finished in 0.003641366958618164 second(s)
# Total loss calculation finished in 0.0006639957427978516 second(s)
# Back propagation finished in 0.003868579864501953 second(s)
# Total loss calculation finished in 0.0006101131439208984 second(s)
# Back propagation finished in 0.003490924835205078 second(s)
# Total loss calculation finished in 5.5789947509765625e-05 second(s)
# Back propagation finished in 0.0035521984100341797 second(s)
# Total loss calculation finished in 0.00027251243591308594 second(s)
# Back propagation finished in 0.003598928451538086 second(s)
# Total loss calculation finished in 0.0007283687591552734 second(s)
# Back propagation finished in 0.0036973953247070312 second(s)
# Total loss calculation finished in 0.0004544258117675781 second(s)
# Back propagation finished in 0.0036306381225585938 second(s)
# Total loss calculation finished in 0.0006775856018066406 second(s)
# Back propagation finished in 0.006183147430419922 second(s)
# Total loss calculation finished in 5.1021575927734375e-05 second(s)
# Back propagation finished in 0.003835916519165039 second(s)
# Total loss calculation finished in 0.00022339820861816406 second(s)
# Back propagation finished in 0.003542184829711914 second(s)
# Total loss calculation finished in 5.650520324707031e-05 second(s)
# Back propagation finished in 0.0035851001739501953 second(s)
# Total loss calculation finished in 4.363059997558594e-05 second(s)
# Back propagation finished in 0.0035104751586914062 second(s)
# Total loss calculation finished in 0.0002601146697998047 second(s)
# Back propagation finished in 0.003874063491821289 second(s)
# Total loss calculation finished in 5.53131103515625e-05 second(s)
# Back propagation finished in 0.004846096038818359 second(s)
# Total loss calculation finished in 9.322166442871094e-05 second(s)
# Back propagation finished in 0.004079580307006836 second(s)
# Total loss calculation finished in 7.295608520507812e-05 second(s)
# Back propagation finished in 0.0035893917083740234 second(s)
# Total loss calculation finished in 5.817413330078125e-05 second(s)
# Back propagation finished in 0.004825115203857422 second(s)
# Total loss calculation finished in 8.463859558105469e-05 second(s)
# Back propagation finished in 0.004443645477294922 second(s)
# Total loss calculation finished in 4.458427429199219e-05 second(s)
# Back propagation finished in 0.004669904708862305 second(s)
# Total loss calculation finished in 3.743171691894531e-05 second(s)
# Back propagation finished in 0.005194902420043945 second(s)
# Total loss calculation finished in 4.887580871582031e-05 second(s)
# Back propagation finished in 0.005109071731567383 second(s)
# Total loss calculation finished in 0.0012497901916503906 second(s)
# Back propagation finished in 0.003606081008911133 second(s)
# Total loss calculation finished in 0.0006735324859619141 second(s)
# Back propagation finished in 0.003584623336791992 second(s)
# Total loss calculation finished in 0.0006961822509765625 second(s)
# Back propagation finished in 0.0035343170166015625 second(s)
# Total loss calculation finished in 0.000667572021484375 second(s)
# Back propagation finished in 0.0036618709564208984 second(s)
# Total loss calculation finished in 0.0006699562072753906 second(s)
# Back propagation finished in 0.003611326217651367 second(s)
# Total loss calculation finished in 0.0007345676422119141 second(s)
# Back propagation finished in 0.003577709197998047 second(s)
# Total loss calculation finished in 0.0006499290466308594 second(s)
# Back propagation finished in 0.0035724639892578125 second(s)
# Total loss calculation finished in 0.0006453990936279297 second(s)
# Back propagation finished in 0.0036194324493408203 second(s)
# Total loss calculation finished in 0.0006349086761474609 second(s)
# Back propagation finished in 0.003566265106201172 second(s)
# Total loss calculation finished in 0.0007181167602539062 second(s)
# Back propagation finished in 0.00426173210144043 second(s)
# Total loss calculation finished in 0.001190185546875 second(s)
# Back propagation finished in 0.004143953323364258 second(s)
# Total loss calculation finished in 0.0007395744323730469 second(s)
# Back propagation finished in 0.0036513805389404297 second(s)
# Total loss calculation finished in 4.3392181396484375e-05 second(s)
# Back propagation finished in 0.0036988258361816406 second(s)
# Total loss calculation finished in 0.0007495880126953125 second(s)
# Back propagation finished in 0.0035943984985351562 second(s)
# Total loss calculation finished in 0.0006654262542724609 second(s)
# Back propagation finished in 0.003710508346557617 second(s)
# Total loss calculation finished in 0.0008180141448974609 second(s)
# Back propagation finished in 0.003662109375 second(s)
# Total loss calculation finished in 0.0007777214050292969 second(s)
# Back propagation finished in 0.0036857128143310547 second(s)
# Total loss calculation finished in 6.389617919921875e-05 second(s)
# Back propagation finished in 0.003727436065673828 second(s)
# Total loss calculation finished in 0.0007257461547851562 second(s)
# Back propagation finished in 0.003639698028564453 second(s)
# Total loss calculation finished in 0.0006601810455322266 second(s)
# Back propagation finished in 0.00360870361328125 second(s)
# Total loss calculation finished in 0.0006897449493408203 second(s)
# Back propagation finished in 0.003637552261352539 second(s)
# Total loss calculation finished in 0.000751495361328125 second(s)
# Back propagation finished in 0.003629922866821289 second(s)
# Total loss calculation finished in 0.0007588863372802734 second(s)
# Back propagation finished in 0.003571748733520508 second(s)
# Total loss calculation finished in 0.0007050037384033203 second(s)
# Back propagation finished in 0.0035309791564941406 second(s)
# Total loss calculation finished in 0.000743865966796875 second(s)
# Back propagation finished in 0.0035860538482666016 second(s)
# Total loss calculation finished in 4.315376281738281e-05 second(s)
# Back propagation finished in 0.0035195350646972656 second(s)
# Total loss calculation finished in 0.0007798671722412109 second(s)
# Back propagation finished in 0.003573179244995117 second(s)
# Total loss calculation finished in 0.0006656646728515625 second(s)
# Back propagation finished in 0.0037114620208740234 second(s)
# Total loss calculation finished in 0.0006949901580810547 second(s)
# Back propagation finished in 0.0035872459411621094 second(s)
# Total loss calculation finished in 0.00067138671875 second(s)
# Back propagation finished in 0.0036780834197998047 second(s)
# Total loss calculation finished in 0.0007917881011962891 second(s)
# Back propagation finished in 0.003760099411010742 second(s)
# Total loss calculation finished in 0.0007183551788330078 second(s)
# Back propagation finished in 0.003579854965209961 second(s)
# Total loss calculation finished in 0.0007455348968505859 second(s)
# Back propagation finished in 0.004957675933837891 second(s)
# Total loss calculation finished in 5.7697296142578125e-05 second(s)
# Back propagation finished in 0.004103899002075195 second(s)
# Total loss calculation finished in 4.363059997558594e-05 second(s)
# Back propagation finished in 0.004097461700439453 second(s)
# Total loss calculation finished in 3.743171691894531e-05 second(s)
# Back propagation finished in 0.00619053840637207 second(s)
# Total loss calculation finished in 0.0013124942779541016 second(s)
# Back propagation finished in 0.0035674571990966797 second(s)
# Total loss calculation finished in 0.0006659030914306641 second(s)
# Back propagation finished in 0.003478527069091797 second(s)
# Total loss calculation finished in 0.0007297992706298828 second(s)
# Back propagation finished in 0.0034999847412109375 second(s)
# Total loss calculation finished in 0.00067901611328125 second(s)
# Back propagation finished in 0.0035257339477539062 second(s)
# Total loss calculation finished in 4.57763671875e-05 second(s)
# Back propagation finished in 0.0034661293029785156 second(s)
# Total loss calculation finished in 0.0006906986236572266 second(s)
# Back propagation finished in 0.0034704208374023438 second(s)
# Total loss calculation finished in 0.0006780624389648438 second(s)
# Back propagation finished in 0.004385709762573242 second(s)
# Total loss calculation finished in 5.602836608886719e-05 second(s)
# Back propagation finished in 0.0066683292388916016 second(s)
# Total loss calculation finished in 0.0006763935089111328 second(s)
# Back propagation finished in 0.003466367721557617 second(s)
# Total loss calculation finished in 0.0006811618804931641 second(s)
# Back propagation finished in 0.0035140514373779297 second(s)
# Total loss calculation finished in 0.0006222724914550781 second(s)
# Back propagation finished in 0.003445863723754883 second(s)
# Total loss calculation finished in 0.0006308555603027344 second(s)
# Back propagation finished in 0.003439188003540039 second(s)
# Total loss calculation finished in 0.0006766319274902344 second(s)
# Back propagation finished in 0.003423929214477539 second(s)
# Total loss calculation finished in 0.0006654262542724609 second(s)
# Back propagation finished in 0.0034122467041015625 second(s)
# Total loss calculation finished in 5.817413330078125e-05 second(s)
# Back propagation finished in 0.0034699440002441406 second(s)
# Total loss calculation finished in 0.0006835460662841797 second(s)
# Back propagation finished in 0.0035321712493896484 second(s)
# Total loss calculation finished in 0.00045800209045410156 second(s)
# Back propagation finished in 0.00347137451171875 second(s)
# Total loss calculation finished in 0.0006377696990966797 second(s)
# Back propagation finished in 0.0034401416778564453 second(s)
# Total loss calculation finished in 0.0006709098815917969 second(s)
# Back propagation finished in 0.0035560131072998047 second(s)
# Total loss calculation finished in 0.0006732940673828125 second(s)
# Back propagation finished in 0.003505229949951172 second(s)
# Total loss calculation finished in 0.0007200241088867188 second(s)
# Back propagation finished in 0.004281044006347656 second(s)
# Total loss calculation finished in 0.0007033348083496094 second(s)
# Back propagation finished in 0.0034825801849365234 second(s)
# Total loss calculation finished in 0.0006184577941894531 second(s)
# Back propagation finished in 0.003435373306274414 second(s)
# Total loss calculation finished in 0.0006284713745117188 second(s)
# Back propagation finished in 0.003536701202392578 second(s)
# Total loss calculation finished in 0.00067901611328125 second(s)
# Back propagation finished in 0.0038704872131347656 second(s)
# Total loss calculation finished in 0.0006611347198486328 second(s)
# Back propagation finished in 0.0035490989685058594 second(s)
# Total loss calculation finished in 0.0006403923034667969 second(s)
# Back propagation finished in 0.0034835338592529297 second(s)
# Total loss calculation finished in 0.0006792545318603516 second(s)
# Back propagation finished in 0.0034952163696289062 second(s)
# Total loss calculation finished in 0.0009562969207763672 second(s)
# Back propagation finished in 0.0034444332122802734 second(s)
# Total loss calculation finished in 5.8650970458984375e-05 second(s)
# Back propagation finished in 0.003516674041748047 second(s)
# Total loss calculation finished in 0.000705718994140625 second(s)
# Back propagation finished in 0.0034477710723876953 second(s)
# Total loss calculation finished in 0.0006680488586425781 second(s)
# Back propagation finished in 0.003432750701904297 second(s)
# Total loss calculation finished in 0.0007107257843017578 second(s)
# Back propagation finished in 0.003663778305053711 second(s)
# Total loss calculation finished in 0.0007736682891845703 second(s)
# Back propagation finished in 0.0036115646362304688 second(s)
# Total loss calculation finished in 0.0007836818695068359 second(s)
# Back propagation finished in 0.0035517215728759766 second(s)
# Total loss calculation finished in 0.000667572021484375 second(s)
# Back propagation finished in 0.004575014114379883 second(s)
# Total loss calculation finished in 5.0067901611328125e-05 second(s)
# Back propagation finished in 0.004079103469848633 second(s)
# Total loss calculation finished in 5.1021575927734375e-05 second(s)
# Back propagation finished in 0.004161834716796875 second(s)
# Total loss calculation finished in 3.504753112792969e-05 second(s)
# Back propagation finished in 0.004941701889038086 second(s)
# Total loss calculation finished in 4.863739013671875e-05 second(s)
# Back propagation finished in 0.0035886764526367188 second(s)
# Total loss calculation finished in 0.00047087669372558594 second(s)
# Back propagation finished in 0.0035398006439208984 second(s)
# Total loss calculation finished in 0.0007138252258300781 second(s)
# Back propagation finished in 0.003603219985961914 second(s)
# Total loss calculation finished in 5.888938903808594e-05 second(s)
# Back propagation finished in 0.0036783218383789062 second(s)
# Total loss calculation finished in 0.0006892681121826172 second(s)
# Back propagation finished in 0.0035581588745117188 second(s)
# Total loss calculation finished in 0.00047707557678222656 second(s)
# Back propagation finished in 0.0035178661346435547 second(s)
# Total loss calculation finished in 0.00046634674072265625 second(s)
# Back propagation finished in 0.003544330596923828 second(s)
# Total loss calculation finished in 0.0007147789001464844 second(s)
# Back propagation finished in 0.003512859344482422 second(s)
# Total loss calculation finished in 0.0006833076477050781 second(s)
# Back propagation finished in 0.003696441650390625 second(s)
# Total loss calculation finished in 0.0007040500640869141 second(s)
# Back propagation finished in 0.0035343170166015625 second(s)
# Total loss calculation finished in 0.0009496212005615234 second(s)
# Back propagation finished in 0.0038390159606933594 second(s)
# Total loss calculation finished in 0.0007255077362060547 second(s)
# Back propagation finished in 0.003521442413330078 second(s)
# Total loss calculation finished in 0.0006701946258544922 second(s)
# Back propagation finished in 0.003734111785888672 second(s)
# Total loss calculation finished in 6.67572021484375e-05 second(s)
# Back propagation finished in 0.005128383636474609 second(s)
# Total loss calculation finished in 0.002595663070678711 second(s)
# Back propagation finished in 0.003530740737915039 second(s)
# Total loss calculation finished in 4.38690185546875e-05 second(s)
# Back propagation finished in 0.003522157669067383 second(s)
# Total loss calculation finished in 5.221366882324219e-05 second(s)
# Back propagation finished in 0.0036115646362304688 second(s)
# Total loss calculation finished in 0.0007216930389404297 second(s)
# Back propagation finished in 0.003511667251586914 second(s)
# Total loss calculation finished in 0.00044846534729003906 second(s)
# Back propagation finished in 0.0035445690155029297 second(s)
# Total loss calculation finished in 4.6253204345703125e-05 second(s)
# Back propagation finished in 0.0035293102264404297 second(s)
# Total loss calculation finished in 0.0007073879241943359 second(s)
# Back propagation finished in 0.0035114288330078125 second(s)
# Total loss calculation finished in 0.0006587505340576172 second(s)
# Back propagation finished in 0.0037109851837158203 second(s)
# Total loss calculation finished in 0.0006721019744873047 second(s)
# Back propagation finished in 0.0035910606384277344 second(s)
# Total loss calculation finished in 0.0006918907165527344 second(s)
# Back propagation finished in 0.003640413284301758 second(s)
# Total loss calculation finished in 0.0007410049438476562 second(s)
# Back propagation finished in 0.0034966468811035156 second(s)
# Total loss calculation finished in 0.0006818771362304688 second(s)
# Back propagation finished in 0.003573894500732422 second(s)
# Total loss calculation finished in 0.0010802745819091797 second(s)
# Back propagation finished in 0.003673076629638672 second(s)
# Total loss calculation finished in 0.0007579326629638672 second(s)
# Back propagation finished in 0.003650188446044922 second(s)
# Total loss calculation finished in 0.0007612705230712891 second(s)
# Back propagation finished in 0.003686189651489258 second(s)
# Total loss calculation finished in 0.0007319450378417969 second(s)
# Back propagation finished in 0.0035889148712158203 second(s)
# Total loss calculation finished in 0.0007455348968505859 second(s)
# Back propagation finished in 0.003670930862426758 second(s)
# Total loss calculation finished in 0.0007569789886474609 second(s)
# Back propagation finished in 0.0036191940307617188 second(s)
# Total loss calculation finished in 0.0007634162902832031 second(s)
# Back propagation finished in 0.003650665283203125 second(s)
# Total loss calculation finished in 0.0008335113525390625 second(s)
# Back propagation finished in 0.005135536193847656 second(s)
# Total loss calculation finished in 0.0005848407745361328 second(s)
# Back propagation finished in 0.004503011703491211 second(s)
# Total loss calculation finished in 5.316734313964844e-05 second(s)
# Back propagation finished in 0.0045773983001708984 second(s)
# Total loss calculation finished in 4.291534423828125e-05 second(s)
# Back propagation finished in 0.006028652191162109 second(s)
# Total loss calculation finished in 0.0014443397521972656 second(s)
# Back propagation finished in 0.0042264461517333984 second(s)
# Total loss calculation finished in 0.0008978843688964844 second(s)
# Back propagation finished in 0.0037474632263183594 second(s)
# Total loss calculation finished in 0.0007567405700683594 second(s)
# Back propagation finished in 0.0035326480865478516 second(s)
# Total loss calculation finished in 0.0006606578826904297 second(s)
# Back propagation finished in 0.003521442413330078 second(s)
# Total loss calculation finished in 0.0006844997406005859 second(s)
# Back propagation finished in 0.003479480743408203 second(s)
# Total loss calculation finished in 0.0006985664367675781 second(s)
# Back propagation finished in 0.003537893295288086 second(s)
# Total loss calculation finished in 0.0007312297821044922 second(s)
# Back propagation finished in 0.0035429000854492188 second(s)
# Total loss calculation finished in 0.0007073879241943359 second(s)
# Back propagation finished in 0.003579378128051758 second(s)
# Total loss calculation finished in 0.0006744861602783203 second(s)
# Back propagation finished in 0.0034656524658203125 second(s)
# Total loss calculation finished in 0.0006196498870849609 second(s)
# Back propagation finished in 0.0034186840057373047 second(s)
# Total loss calculation finished in 0.0006532669067382812 second(s)
# Back propagation finished in 0.0034613609313964844 second(s)
# Total loss calculation finished in 0.0006577968597412109 second(s)
# Back propagation finished in 0.003462553024291992 second(s)
# Total loss calculation finished in 0.0006804466247558594 second(s)
# Back propagation finished in 0.0035371780395507812 second(s)
# Total loss calculation finished in 0.0007030963897705078 second(s)
# Back propagation finished in 0.0035538673400878906 second(s)
# Total loss calculation finished in 0.0006933212280273438 second(s)
# Back propagation finished in 0.003452301025390625 second(s)
# Total loss calculation finished in 0.0006885528564453125 second(s)
# Back propagation finished in 0.003476381301879883 second(s)
# Total loss calculation finished in 0.0006835460662841797 second(s)
# Back propagation finished in 0.0034813880920410156 second(s)
# Total loss calculation finished in 0.0006995201110839844 second(s)
# Back propagation finished in 0.0034754276275634766 second(s)
# Total loss calculation finished in 0.0007565021514892578 second(s)
# Back propagation finished in 0.003528594970703125 second(s)
# Total loss calculation finished in 0.0006837844848632812 second(s)
# Back propagation finished in 0.0034613609313964844 second(s)
# Total loss calculation finished in 0.0006866455078125 second(s)
# Back propagation finished in 0.0035076141357421875 second(s)
# Total loss calculation finished in 0.0006897449493408203 second(s)
# Back propagation finished in 0.003513336181640625 second(s)
# Total loss calculation finished in 0.0007109642028808594 second(s)
# Back propagation finished in 0.003466367721557617 second(s)
# Total loss calculation finished in 0.0006947517395019531 second(s)
# Back propagation finished in 0.003499269485473633 second(s)
# Total loss calculation finished in 0.0004525184631347656 second(s)
# Back propagation finished in 0.0035212039947509766 second(s)
# Total loss calculation finished in 0.0006864070892333984 second(s)
# Back propagation finished in 0.003617525100708008 second(s)
# Total loss calculation finished in 0.0007693767547607422 second(s)
# Back propagation finished in 0.0035152435302734375 second(s)
# Total loss calculation finished in 0.0006771087646484375 second(s)
# Back propagation finished in 0.0034902095794677734 second(s)
# Total loss calculation finished in 0.0006604194641113281 second(s)
# Back propagation finished in 0.0036568641662597656 second(s)
# Total loss calculation finished in 0.0006804466247558594 second(s)
# Back propagation finished in 0.004741191864013672 second(s)
# Total loss calculation finished in 6.794929504394531e-05 second(s)
# Back propagation finished in 0.004944562911987305 second(s)
# Total loss calculation finished in 4.267692565917969e-05 second(s)
# Back propagation finished in 0.004256010055541992 second(s)
# Total loss calculation finished in 0.0006933212280273438 second(s)
# Back propagation finished in 0.003501415252685547 second(s)
# Total loss calculation finished in 0.0007102489471435547 second(s)
# Back propagation finished in 0.003502368927001953 second(s)
# Total loss calculation finished in 0.0006780624389648438 second(s)
# Back propagation finished in 0.004209280014038086 second(s)
# Total loss calculation finished in 4.863739013671875e-05 second(s)
# Back propagation finished in 0.0043621063232421875 second(s)
# Total loss calculation finished in 4.482269287109375e-05 second(s)
# Back propagation finished in 0.004054546356201172 second(s)
# Total loss calculation finished in 4.5299530029296875e-05 second(s)
# Back propagation finished in 0.0043103694915771484 second(s)
# Total loss calculation finished in 3.504753112792969e-05 second(s)
# Back propagation finished in 0.007694721221923828 second(s)
# Total loss calculation finished in 6.461143493652344e-05 second(s)
# Back propagation finished in 0.0035698413848876953 second(s)
# Total loss calculation finished in 0.0007176399230957031 second(s)
# Back propagation finished in 0.0035097599029541016 second(s)
# Total loss calculation finished in 0.0006742477416992188 second(s)
# Back propagation finished in 0.003506898880004883 second(s)
# Total loss calculation finished in 0.0006628036499023438 second(s)
# Back propagation finished in 0.003530740737915039 second(s)
# Total loss calculation finished in 0.0006897449493408203 second(s)
# Back propagation finished in 0.0035321712493896484 second(s)
# Total loss calculation finished in 0.0006923675537109375 second(s)
# Back propagation finished in 0.0035126209259033203 second(s)
# Total loss calculation finished in 0.0006878376007080078 second(s)
# Back propagation finished in 0.0034754276275634766 second(s)
# Total loss calculation finished in 0.0006520748138427734 second(s)
# Back propagation finished in 0.003490447998046875 second(s)
# Total loss calculation finished in 0.0006608963012695312 second(s)
# Back propagation finished in 0.0034055709838867188 second(s)
# Total loss calculation finished in 4.124641418457031e-05 second(s)
# Back propagation finished in 0.0052607059478759766 second(s)
# Total loss calculation finished in 0.0006706714630126953 second(s)
# Back propagation finished in 0.003628969192504883 second(s)
# Total loss calculation finished in 0.0006949901580810547 second(s)
# Back propagation finished in 0.0035257339477539062 second(s)
# Total loss calculation finished in 0.0007395744323730469 second(s)
# Back propagation finished in 0.0034856796264648438 second(s)
# Total loss calculation finished in 0.0006775856018066406 second(s)
# Back propagation finished in 0.0034563541412353516 second(s)
# Total loss calculation finished in 0.0004532337188720703 second(s)
# Back propagation finished in 0.003458738327026367 second(s)
# Total loss calculation finished in 4.601478576660156e-05 second(s)
# Back propagation finished in 0.0034682750701904297 second(s)
# Total loss calculation finished in 0.0006458759307861328 second(s)
# Back propagation finished in 0.0034542083740234375 second(s)
# Total loss calculation finished in 0.0006213188171386719 second(s)
# Back propagation finished in 0.005079030990600586 second(s)
# Total loss calculation finished in 5.269050598144531e-05 second(s)
# Back propagation finished in 0.004919528961181641 second(s)
# Total loss calculation finished in 5.936622619628906e-05 second(s)
# Back propagation finished in 0.0050089359283447266 second(s)
# Total loss calculation finished in 5.9604644775390625e-05 second(s)
# Back propagation finished in 0.0035390853881835938 second(s)
# Total loss calculation finished in 6.0558319091796875e-05 second(s)
# Back propagation finished in 0.0035054683685302734 second(s)
# Total loss calculation finished in 4.7206878662109375e-05 second(s)
# Back propagation finished in 0.0034515857696533203 second(s)
# Total loss calculation finished in 5.364418029785156e-05 second(s)
# Back propagation finished in 0.0034868717193603516 second(s)
# Total loss calculation finished in 5.316734313964844e-05 second(s)
# Back propagation finished in 0.003406047821044922 second(s)
# Total loss calculation finished in 0.00028133392333984375 second(s)
# Back propagation finished in 0.003446340560913086 second(s)
# Total loss calculation finished in 0.0006787776947021484 second(s)
# Back propagation finished in 0.0035169124603271484 second(s)
# Total loss calculation finished in 0.00046324729919433594 second(s)
# Back propagation finished in 0.003586292266845703 second(s)
# Total loss calculation finished in 0.0006701946258544922 second(s)
# Back propagation finished in 0.0036516189575195312 second(s)
# Total loss calculation finished in 6.604194641113281e-05 second(s)
# Back propagation finished in 0.003637075424194336 second(s)
# Total loss calculation finished in 0.0007293224334716797 second(s)
# Back propagation finished in 0.003605365753173828 second(s)
# Total loss calculation finished in 0.0008058547973632812 second(s)
# Back propagation finished in 0.0036096572875976562 second(s)
# Total loss calculation finished in 4.792213439941406e-05 second(s)
# Back propagation finished in 0.0037021636962890625 second(s)
# Total loss calculation finished in 0.0006890296936035156 second(s)
# Back propagation finished in 0.0034999847412109375 second(s)
# Total loss calculation finished in 0.0007114410400390625 second(s)
# Back propagation finished in 0.003757953643798828 second(s)
# Total loss calculation finished in 0.0006871223449707031 second(s)
# Back propagation finished in 0.004594564437866211 second(s)
# Total loss calculation finished in 5.650520324707031e-05 second(s)
# Back propagation finished in 0.0041544437408447266 second(s)
# Total loss calculation finished in 4.38690185546875e-05 second(s)
# Back propagation finished in 0.004167795181274414 second(s)
# Total loss calculation finished in 3.719329833984375e-05 second(s)
# Back propagation finished in 0.0040400028228759766 second(s)
# Total loss calculation finished in 4.8160552978515625e-05 second(s)
# Back propagation finished in 0.005226612091064453 second(s)
# Total loss calculation finished in 4.458427429199219e-05 second(s)
# Back propagation finished in 0.0036194324493408203 second(s)
# Total loss calculation finished in 0.0007443428039550781 second(s)
# Back propagation finished in 0.0036020278930664062 second(s)
# Total loss calculation finished in 0.0007185935974121094 second(s)
# Back propagation finished in 0.0035855770111083984 second(s)
# Total loss calculation finished in 0.0006854534149169922 second(s)
# Back propagation finished in 0.0035445690155029297 second(s)
# Total loss calculation finished in 0.0007078647613525391 second(s)
# Back propagation finished in 0.003542661666870117 second(s)
# Total loss calculation finished in 0.0032608509063720703 second(s)
# Back propagation finished in 0.004687309265136719 second(s)
# Total loss calculation finished in 6.198883056640625e-05 second(s)
# Back propagation finished in 0.0054934024810791016 second(s)
# Total loss calculation finished in 0.0005495548248291016 second(s)
# Back propagation finished in 0.003599882125854492 second(s)
# Total loss calculation finished in 0.00067138671875 second(s)
# Back propagation finished in 0.003543376922607422 second(s)
# Total loss calculation finished in 0.0006861686706542969 second(s)
# Back propagation finished in 0.003484010696411133 second(s)
# Total loss calculation finished in 0.0006546974182128906 second(s)
# Back propagation finished in 0.0034966468811035156 second(s)
# Total loss calculation finished in 0.0005974769592285156 second(s)
# Back propagation finished in 0.0034449100494384766 second(s)
# Total loss calculation finished in 0.0006501674652099609 second(s)
# Back propagation finished in 0.0035054683685302734 second(s)
# Total loss calculation finished in 0.0010313987731933594 second(s)
# Back propagation finished in 0.0034837722778320312 second(s)
# Total loss calculation finished in 0.0006449222564697266 second(s)
# Back propagation finished in 0.003627777099609375 second(s)
# Total loss calculation finished in 0.0006875991821289062 second(s)
# Back propagation finished in 0.003854036331176758 second(s)
# Total loss calculation finished in 0.00014972686767578125 second(s)
# Back propagation finished in 0.003694772720336914 second(s)
# Total loss calculation finished in 0.0008089542388916016 second(s)
# Back propagation finished in 0.0038900375366210938 second(s)
# Total loss calculation finished in 0.0007834434509277344 second(s)
# Back propagation finished in 0.003645658493041992 second(s)
# Total loss calculation finished in 4.5299530029296875e-05 second(s)
# Back propagation finished in 0.0037393569946289062 second(s)
# Total loss calculation finished in 0.0007014274597167969 second(s)
# Back propagation finished in 0.0035560131072998047 second(s)
# Total loss calculation finished in 0.0006899833679199219 second(s)
# Back propagation finished in 0.003621816635131836 second(s)
# Total loss calculation finished in 0.0007328987121582031 second(s)
# Back propagation finished in 0.003559589385986328 second(s)
# Total loss calculation finished in 0.0006833076477050781 second(s)
# Back propagation finished in 0.0035436153411865234 second(s)
# Total loss calculation finished in 0.0007750988006591797 second(s)
# Back propagation finished in 0.0036325454711914062 second(s)
# Total loss calculation finished in 0.0006978511810302734 second(s)
# Back propagation finished in 0.003573894500732422 second(s)
# Total loss calculation finished in 0.0007178783416748047 second(s)
# Back propagation finished in 0.0038352012634277344 second(s)
# Total loss calculation finished in 0.0006756782531738281 second(s)
# Back propagation finished in 0.004086017608642578 second(s)
# Total loss calculation finished in 0.0007162094116210938 second(s)
# Back propagation finished in 0.0036864280700683594 second(s)
# Total loss calculation finished in 0.0007576942443847656 second(s)
# Back propagation finished in 0.003753662109375 second(s)
# Total loss calculation finished in 0.0006747245788574219 second(s)
# Back propagation finished in 0.00370025634765625 second(s)
# Total loss calculation finished in 0.0007116794586181641 second(s)
# Back propagation finished in 0.0036704540252685547 second(s)
# Total loss calculation finished in 0.0007159709930419922 second(s)
# Back propagation finished in 0.0035979747772216797 second(s)
# Total loss calculation finished in 0.0006902217864990234 second(s)
# Back propagation finished in 0.004545927047729492 second(s)
# Total loss calculation finished in 4.76837158203125e-05 second(s)
# Back propagation finished in 0.004523277282714844 second(s)
# Total loss calculation finished in 6.031990051269531e-05 second(s)
# Back propagation finished in 0.004113197326660156 second(s)
# Total loss calculation finished in 3.695487976074219e-05 second(s)
# Back propagation finished in 0.00511479377746582 second(s)
# Total loss calculation finished in 3.361701965332031e-05 second(s)
# Back propagation finished in 0.004229545593261719 second(s)
# Total loss calculation finished in 4.792213439941406e-05 second(s)
# Back propagation finished in 0.0063321590423583984 second(s)
# Total loss calculation finished in 0.0006279945373535156 second(s)
# Back propagation finished in 0.003634929656982422 second(s)
# Total loss calculation finished in 0.0006582736968994141 second(s)
# Back propagation finished in 0.003489971160888672 second(s)
# Total loss calculation finished in 0.0006492137908935547 second(s)
# Back propagation finished in 0.0035402774810791016 second(s)
# Total loss calculation finished in 5.7220458984375e-05 second(s)
# Back propagation finished in 0.003582000732421875 second(s)
# Total loss calculation finished in 0.0006930828094482422 second(s)
# Back propagation finished in 0.0035784244537353516 second(s)
# Total loss calculation finished in 0.0007166862487792969 second(s)
# Back propagation finished in 0.0035257339477539062 second(s)
# Total loss calculation finished in 0.0006716251373291016 second(s)
# Back propagation finished in 0.003599882125854492 second(s)
# Total loss calculation finished in 0.0007338523864746094 second(s)
# Back propagation finished in 0.003614664077758789 second(s)
# Total loss calculation finished in 0.0005042552947998047 second(s)
# Back propagation finished in 0.0035262107849121094 second(s)
# Total loss calculation finished in 0.0006935596466064453 second(s)
# Back propagation finished in 0.0037899017333984375 second(s)
# Total loss calculation finished in 0.0007567405700683594 second(s)
# Back propagation finished in 0.0035698413848876953 second(s)
# Total loss calculation finished in 0.0007164478302001953 second(s)
# Back propagation finished in 0.0038251876831054688 second(s)
# Total loss calculation finished in 0.0007002353668212891 second(s)
# Back propagation finished in 0.0038635730743408203 second(s)
# Total loss calculation finished in 6.151199340820312e-05 second(s)
# Back propagation finished in 0.0035779476165771484 second(s)
# Total loss calculation finished in 0.0007312297821044922 second(s)
# Back propagation finished in 0.003542184829711914 second(s)
# Total loss calculation finished in 0.0007035732269287109 second(s)
# Back propagation finished in 0.003549814224243164 second(s)
# Total loss calculation finished in 0.0007061958312988281 second(s)
# Back propagation finished in 0.003514528274536133 second(s)
# Total loss calculation finished in 0.0006811618804931641 second(s)
# Back propagation finished in 0.00353240966796875 second(s)
# Total loss calculation finished in 0.0006823539733886719 second(s)
# Back propagation finished in 0.003507852554321289 second(s)
# Total loss calculation finished in 0.0006694793701171875 second(s)
# Back propagation finished in 0.0034732818603515625 second(s)
# Total loss calculation finished in 0.0006577968597412109 second(s)
# Back propagation finished in 0.0034744739532470703 second(s)
# Total loss calculation finished in 0.0006649494171142578 second(s)
# Back propagation finished in 0.0034742355346679688 second(s)
# Total loss calculation finished in 5.53131103515625e-05 second(s)
# Back propagation finished in 0.0036013126373291016 second(s)
# Total loss calculation finished in 0.0007233619689941406 second(s)
# Back propagation finished in 0.0034945011138916016 second(s)
# Total loss calculation finished in 0.0006823539733886719 second(s)
# Back propagation finished in 0.003578662872314453 second(s)
# Total loss calculation finished in 0.0006549358367919922 second(s)
# Back propagation finished in 0.0034592151641845703 second(s)
# Total loss calculation finished in 0.00037860870361328125 second(s)
# Back propagation finished in 0.0034286975860595703 second(s)
# Total loss calculation finished in 0.0006144046783447266 second(s)
# Back propagation finished in 0.0034151077270507812 second(s)
# Total loss calculation finished in 0.0006124973297119141 second(s)
# Back propagation finished in 0.003488302230834961 second(s)
# Total loss calculation finished in 0.0006895065307617188 second(s)
# Back propagation finished in 0.0034227371215820312 second(s)
# Total loss calculation finished in 0.0006763935089111328 second(s)
# Back propagation finished in 0.003496885299682617 second(s)
# Total loss calculation finished in 0.0007097721099853516 second(s)
# Back propagation finished in 0.003506898880004883 second(s)
# Total loss calculation finished in 0.000644683837890625 second(s)
# Back propagation finished in 0.0037446022033691406 second(s)
# Total loss calculation finished in 0.0018510818481445312 second(s)
# Back propagation finished in 0.004308462142944336 second(s)
# Total loss calculation finished in 4.744529724121094e-05 second(s)
# Back propagation finished in 0.004037141799926758 second(s)
# Total loss calculation finished in 8.177757263183594e-05 second(s)
# Back propagation finished in 0.004144191741943359 second(s)
# Total loss calculation finished in 6.365776062011719e-05 second(s)
# Back propagation finished in 0.005259037017822266 second(s)
# Total loss calculation finished in 0.0006833076477050781 second(s)
# Back propagation finished in 0.005223274230957031 second(s)
# Total loss calculation finished in 0.00010251998901367188 second(s)
# Back propagation finished in 0.004446983337402344 second(s)
# Total loss calculation finished in 0.0007002353668212891 second(s)
# Back propagation finished in 0.003709554672241211 second(s)
# Total loss calculation finished in 0.0007290840148925781 second(s)
# Back propagation finished in 0.005883216857910156 second(s)
# Total loss calculation finished in 0.0007336139678955078 second(s)
# Back propagation finished in 0.0036859512329101562 second(s)
# Total loss calculation finished in 0.0005154609680175781 second(s)
# Back propagation finished in 0.003762483596801758 second(s)
# Total loss calculation finished in 3.4809112548828125e-05 second(s)
# Back propagation finished in 0.00452733039855957 second(s)
# Total loss calculation finished in 0.0006814002990722656 second(s)
# Back propagation finished in 0.0035636425018310547 second(s)
# Total loss calculation finished in 0.0007371902465820312 second(s)
# Back propagation finished in 0.00408935546875 second(s)
# Total loss calculation finished in 0.0008795261383056641 second(s)
# Back propagation finished in 0.0036482810974121094 second(s)
# Total loss calculation finished in 0.001020669937133789 second(s)
# Back propagation finished in 0.003710508346557617 second(s)
# Total loss calculation finished in 0.0007300376892089844 second(s)
# Back propagation finished in 0.0040853023529052734 second(s)
# Total loss calculation finished in 0.0007472038269042969 second(s)
# Back propagation finished in 0.0036437511444091797 second(s)
# Total loss calculation finished in 0.0006809234619140625 second(s)
# Back propagation finished in 0.003591299057006836 second(s)
# Total loss calculation finished in 0.0006792545318603516 second(s)
# Back propagation finished in 0.0036857128143310547 second(s)
# Total loss calculation finished in 0.0007855892181396484 second(s)
# Back propagation finished in 0.003831624984741211 second(s)
# Total loss calculation finished in 0.0006389617919921875 second(s)
# Back propagation finished in 0.003751993179321289 second(s)
# Total loss calculation finished in 0.0007159709930419922 second(s)
# Back propagation finished in 0.003777742385864258 second(s)
# Total loss calculation finished in 0.0007007122039794922 second(s)
# Back propagation finished in 0.0037245750427246094 second(s)
# Total loss calculation finished in 0.0007145404815673828 second(s)
# Back propagation finished in 0.0036869049072265625 second(s)
# Total loss calculation finished in 0.0007069110870361328 second(s)
# Back propagation finished in 0.003963470458984375 second(s)
# Total loss calculation finished in 0.000461578369140625 second(s)
# Back propagation finished in 0.0037240982055664062 second(s)
# Total loss calculation finished in 0.000469207763671875 second(s)
# Back propagation finished in 0.0037288665771484375 second(s)
# Total loss calculation finished in 0.0007505416870117188 second(s)
# Back propagation finished in 0.003530263900756836 second(s)
# Total loss calculation finished in 0.0007619857788085938 second(s)
# Back propagation finished in 0.003612518310546875 second(s)
# Total loss calculation finished in 0.0007579326629638672 second(s)
# Back propagation finished in 0.003769397735595703 second(s)
# Total loss calculation finished in 0.0007326602935791016 second(s)
# Back propagation finished in 0.0036954879760742188 second(s)
# Total loss calculation finished in 0.0008664131164550781 second(s)
# Back propagation finished in 0.00374603271484375 second(s)
# Total loss calculation finished in 0.0007760524749755859 second(s)
# Back propagation finished in 0.0036242008209228516 second(s)
# Total loss calculation finished in 0.0006642341613769531 second(s)
# Back propagation finished in 0.0035963058471679688 second(s)
# Total loss calculation finished in 0.0007183551788330078 second(s)
# Back propagation finished in 0.003578662872314453 second(s)
# Total loss calculation finished in 0.0007309913635253906 second(s)
# Back propagation finished in 0.0035932064056396484 second(s)
# Total loss calculation finished in 0.0007176399230957031 second(s)
# Back propagation finished in 0.003560304641723633 second(s)
# Total loss calculation finished in 0.0017778873443603516 second(s)
# Back propagation finished in 0.0041081905364990234 second(s)
# Total loss calculation finished in 7.510185241699219e-05 second(s)
# Back propagation finished in 0.004050016403198242 second(s)
# Total loss calculation finished in 3.4809112548828125e-05 second(s)
# Back propagation finished in 0.004126310348510742 second(s)
# Total loss calculation finished in 3.886222839355469e-05 second(s)
# Back propagation finished in 0.006353139877319336 second(s)
# Total loss calculation finished in 3.337860107421875e-05 second(s)
# Back propagation finished in 0.0052967071533203125 second(s)
# Total loss calculation finished in 0.0005447864532470703 second(s)
# Back propagation finished in 0.003692150115966797 second(s)
# Total loss calculation finished in 4.291534423828125e-05 second(s)
# Back propagation finished in 0.0035600662231445312 second(s)
# Total loss calculation finished in 4.649162292480469e-05 second(s)
# Back propagation finished in 0.003507852554321289 second(s)
# Total loss calculation finished in 4.6253204345703125e-05 second(s)
# Back propagation finished in 0.0034551620483398438 second(s)
# Total loss calculation finished in 5.602836608886719e-05 second(s)
# Back propagation finished in 0.003612995147705078 second(s)
# Total loss calculation finished in 4.8160552978515625e-05 second(s)
# Back propagation finished in 0.003559112548828125 second(s)
# Total loss calculation finished in 5.53131103515625e-05 second(s)
# Back propagation finished in 0.0035767555236816406 second(s)
# Total loss calculation finished in 5.53131103515625e-05 second(s)
# Back propagation finished in 0.0035314559936523438 second(s)
# Total loss calculation finished in 4.8160552978515625e-05 second(s)
# Back propagation finished in 0.0034942626953125 second(s)
# Total loss calculation finished in 0.00026535987854003906 second(s)
# Back propagation finished in 0.003497600555419922 second(s)
# Total loss calculation finished in 0.0007007122039794922 second(s)
# Back propagation finished in 0.0035042762756347656 second(s)
# Total loss calculation finished in 0.0007712841033935547 second(s)
# Back propagation finished in 0.003523588180541992 second(s)
# Total loss calculation finished in 0.0006971359252929688 second(s)
# Back propagation finished in 0.003444194793701172 second(s)
# Total loss calculation finished in 0.00067138671875 second(s)
# Back propagation finished in 0.003509521484375 second(s)
# Total loss calculation finished in 0.0006833076477050781 second(s)
# Back propagation finished in 0.0035104751586914062 second(s)
# Total loss calculation finished in 0.0007116794586181641 second(s)
# Back propagation finished in 0.0046117305755615234 second(s)
# Total loss calculation finished in 8.225440979003906e-05 second(s)
# Back propagation finished in 0.004770517349243164 second(s)
# Total loss calculation finished in 7.462501525878906e-05 second(s)
# Back propagation finished in 0.003742218017578125 second(s)
# Total loss calculation finished in 4.935264587402344e-05 second(s)
# Back propagation finished in 0.003607034683227539 second(s)
# Total loss calculation finished in 4.792213439941406e-05 second(s)
# Back propagation finished in 0.00374603271484375 second(s)
# Total loss calculation finished in 0.000698089599609375 second(s)
# Back propagation finished in 0.003493785858154297 second(s)
# Total loss calculation finished in 0.0006725788116455078 second(s)
# Back propagation finished in 0.0035550594329833984 second(s)
# Total loss calculation finished in 0.00045871734619140625 second(s)
# Back propagation finished in 0.0035724639892578125 second(s)
# Total loss calculation finished in 0.0006732940673828125 second(s)
# Back propagation finished in 0.0035982131958007812 second(s)
# Total loss calculation finished in 0.0007393360137939453 second(s)
# Back propagation finished in 0.0035011768341064453 second(s)
# Total loss calculation finished in 0.0006923675537109375 second(s)
# Back propagation finished in 0.003934621810913086 second(s)
# Total loss calculation finished in 0.0007307529449462891 second(s)
# Back propagation finished in 0.003576993942260742 second(s)
# Total loss calculation finished in 0.0006861686706542969 second(s)
# Back propagation finished in 0.0036058425903320312 second(s)
# Total loss calculation finished in 0.0007004737854003906 second(s)
# Back propagation finished in 0.0034847259521484375 second(s)
# Total loss calculation finished in 0.0006701946258544922 second(s)
# Back propagation finished in 0.006507396697998047 second(s)
# Total loss calculation finished in 0.0007255077362060547 second(s)
# Back propagation finished in 0.0035691261291503906 second(s)
# Total loss calculation finished in 0.0006983280181884766 second(s)
# Back propagation finished in 0.0035424232482910156 second(s)
# ...
# Back propagation finished in 0.0038840770721435547 second(s)
# Total loss calculation finished in 0.0007550716400146484 second(s)
# Back propagation finished in 0.003786802291870117 second(s)
# Total loss calculation finished in 0.00075531005859375 second(s)
# Back propagation finished in 0.004236936569213867 second(s)
# Total loss calculation finished in 7.581710815429688e-05 second(s)
# Back propagation finished in 0.0038988590240478516 second(s)
# Total loss calculation finished in 0.0009279251098632812 second(s)
# Back propagation finished in 0.003828763961791992 second(s)
# Total loss calculation finished in 0.0008232593536376953 second(s)
# Back propagation finished in 0.003774404525756836 second(s)
# Total loss calculation finished in 0.0009593963623046875 second(s)
# Back propagation finished in 0.0037271976470947266 second(s)
# Total loss calculation finished in 0.0007042884826660156 second(s)
# Back propagation finished in 0.0037174224853515625 second(s)
# Total loss calculation finished in 0.0007510185241699219 second(s)
# Back propagation finished in 0.0037195682525634766 second(s)
# Total loss calculation finished in 0.0007805824279785156 second(s)
# Back propagation finished in 0.0035734176635742188 second(s)
# Total loss calculation finished in 0.000720977783203125 second(s)
# Back propagation finished in 0.003642559051513672 second(s)
# Total loss calculation finished in 0.0006291866302490234 second(s)
# Back propagation finished in 0.0038404464721679688 second(s)
# Total loss calculation finished in 0.00093841552734375 second(s)
# Back propagation finished in 0.003712892532348633 second(s)
# Total loss calculation finished in 0.000461578369140625 second(s)
# Back propagation finished in 0.003658294677734375 second(s)
# Total loss calculation finished in 0.0006644725799560547 second(s)
# Back propagation finished in 0.003576517105102539 second(s)
# Total loss calculation finished in 0.0006189346313476562 second(s)
# Back propagation finished in 0.003611326217651367 second(s)
# Total loss calculation finished in 0.0007152557373046875 second(s)
# Back propagation finished in 0.0035703182220458984 second(s)
# Total loss calculation finished in 4.506111145019531e-05 second(s)
# Back propagation finished in 0.0036547183990478516 second(s)
# Total loss calculation finished in 0.00047278404235839844 second(s)
# Back propagation finished in 0.003654956817626953 second(s)
# Total loss calculation finished in 0.0007114410400390625 second(s)
# Back propagation finished in 0.003580808639526367 second(s)
# Total loss calculation finished in 0.0007107257843017578 second(s)
# Back propagation finished in 0.003573179244995117 second(s)
# Total loss calculation finished in 0.0006215572357177734 second(s)
# Back propagation finished in 0.0035545825958251953 second(s)
# Total loss calculation finished in 0.0007100105285644531 second(s)
# Back propagation finished in 0.0035762786865234375 second(s)
# Total loss calculation finished in 0.0007243156433105469 second(s)
# Back propagation finished in 0.0035271644592285156 second(s)
# Total loss calculation finished in 0.0006394386291503906 second(s)
# Back propagation finished in 0.0036551952362060547 second(s)
# Total loss calculation finished in 0.000667572021484375 second(s)
# Back propagation finished in 0.003655672073364258 second(s)
# Total loss calculation finished in 0.0007619857788085938 second(s)
# Back propagation finished in 0.003597736358642578 second(s)
# Total loss calculation finished in 0.0007030963897705078 second(s)
# Back propagation finished in 0.003605365753173828 second(s)
# Total loss calculation finished in 0.0006680488586425781 second(s)
# Back propagation finished in 0.006704568862915039 second(s)
# Total loss calculation finished in 0.0008363723754882812 second(s)
# Back propagation finished in 0.007668018341064453 second(s)
# Total loss calculation finished in 6.914138793945312e-05 second(s)
# Back propagation finished in 0.004270792007446289 second(s)
# Total loss calculation finished in 5.1975250244140625e-05 second(s)
# Back propagation finished in 0.0042383670806884766 second(s)
# Total loss calculation finished in 5.745887756347656e-05 second(s)
# Back propagation finished in 0.004195690155029297 second(s)
# Total loss calculation finished in 5.507469177246094e-05 second(s)
# Back propagation finished in 0.004292488098144531 second(s)
# Total loss calculation finished in 6.461143493652344e-05 second(s)
# Back propagation finished in 0.004261970520019531 second(s)
# Total loss calculation finished in 0.0002999305725097656 second(s)
# Back propagation finished in 0.0037131309509277344 second(s)
# Total loss calculation finished in 0.0007071495056152344 second(s)
# Back propagation finished in 0.0036711692810058594 second(s)
# Total loss calculation finished in 0.0006825923919677734 second(s)
# Back propagation finished in 0.0038743019104003906 second(s)
# Total loss calculation finished in 0.0007157325744628906 second(s)
# Back propagation finished in 0.0036401748657226562 second(s)
# Total loss calculation finished in 0.0006968975067138672 second(s)
# Back propagation finished in 0.0036039352416992188 second(s)
# Total loss calculation finished in 0.00080108642578125 second(s)
# Back propagation finished in 0.003941535949707031 second(s)
# Total loss calculation finished in 6.246566772460938e-05 second(s)
# Back propagation finished in 0.004368782043457031 second(s)
# Total loss calculation finished in 0.0006401538848876953 second(s)
# Back propagation finished in 0.003667116165161133 second(s)
# Total loss calculation finished in 0.0009295940399169922 second(s)
# Back propagation finished in 0.0037162303924560547 second(s)
# Total loss calculation finished in 0.0007550716400146484 second(s)
# Back propagation finished in 0.0035986900329589844 second(s)
# Total loss calculation finished in 0.0007174015045166016 second(s)
# Back propagation finished in 0.0036733150482177734 second(s)
# Total loss calculation finished in 4.696846008300781e-05 second(s)
# Back propagation finished in 0.0038814544677734375 second(s)
# Total loss calculation finished in 0.0009465217590332031 second(s)
# Back propagation finished in 0.0037000179290771484 second(s)
# Total loss calculation finished in 0.0007369518280029297 second(s)
# Back propagation finished in 0.0036728382110595703 second(s)
# Total loss calculation finished in 0.0006833076477050781 second(s)
# Back propagation finished in 0.003738880157470703 second(s)
# Total loss calculation finished in 0.000698089599609375 second(s)
# Back propagation finished in 0.0036776065826416016 second(s)
# Total loss calculation finished in 0.0007278919219970703 second(s)
# Back propagation finished in 0.0036520957946777344 second(s)
# Total loss calculation finished in 0.0007302761077880859 second(s)
# Back propagation finished in 0.0036780834197998047 second(s)
# Total loss calculation finished in 0.0008249282836914062 second(s)
# Back propagation finished in 0.0036826133728027344 second(s)
# Total loss calculation finished in 0.0007045269012451172 second(s)
# Back propagation finished in 0.003666400909423828 second(s)
# Total loss calculation finished in 0.0006592273712158203 second(s)
# Back propagation finished in 0.0036585330963134766 second(s)
# Total loss calculation finished in 0.0007073879241943359 second(s)
# Back propagation finished in 0.0036377906799316406 second(s)
# Total loss calculation finished in 0.0006840229034423828 second(s)
# Back propagation finished in 0.0036346912384033203 second(s)
# Total loss calculation finished in 6.198883056640625e-05 second(s)
# Back propagation finished in 0.0036551952362060547 second(s)
# Total loss calculation finished in 0.0008673667907714844 second(s)
# Back propagation finished in 0.004171848297119141 second(s)
# Total loss calculation finished in 7.390975952148438e-05 second(s)
# Back propagation finished in 0.00411677360534668 second(s)
# Total loss calculation finished in 6.580352783203125e-05 second(s)
# Back propagation finished in 0.0048716068267822266 second(s)
# Total loss calculation finished in 0.0007703304290771484 second(s)
# Back propagation finished in 0.005317211151123047 second(s)
# Total loss calculation finished in 6.818771362304688e-05 second(s)
# Back propagation finished in 0.0042476654052734375 second(s)
# Total loss calculation finished in 8.368492126464844e-05 second(s)
# Back propagation finished in 0.004579782485961914 second(s)
# Total loss calculation finished in 5.91278076171875e-05 second(s)
# Back propagation finished in 0.0041828155517578125 second(s)
# Total loss calculation finished in 5.555152893066406e-05 second(s)
# Back propagation finished in 0.004108905792236328 second(s)
# Total loss calculation finished in 5.459785461425781e-05 second(s)
# Back propagation finished in 0.004089832305908203 second(s)
# Total loss calculation finished in 5.0067901611328125e-05 second(s)
# Back propagation finished in 0.003933906555175781 second(s)
# Total loss calculation finished in 5.936622619628906e-05 second(s)
# Back propagation finished in 0.00406336784362793 second(s)
# Total loss calculation finished in 4.839897155761719e-05 second(s)
# Back propagation finished in 0.0041921138763427734 second(s)
# Total loss calculation finished in 5.91278076171875e-05 second(s)
# Back propagation finished in 0.0037086009979248047 second(s)
# Total loss calculation finished in 7.343292236328125e-05 second(s)
# Back propagation finished in 0.003718137741088867 second(s)
# Total loss calculation finished in 7.104873657226562e-05 second(s)
# Back propagation finished in 0.0036821365356445312 second(s)
# Total loss calculation finished in 0.0006816387176513672 second(s)
# Back propagation finished in 0.0036420822143554688 second(s)
# Total loss calculation finished in 0.0006823539733886719 second(s)
# Back propagation finished in 0.0035886764526367188 second(s)
# Total loss calculation finished in 0.00061798095703125 second(s)
# Back propagation finished in 0.0036079883575439453 second(s)
# Total loss calculation finished in 0.0006361007690429688 second(s)
# Back propagation finished in 0.0036170482635498047 second(s)
# Total loss calculation finished in 0.0006661415100097656 second(s)
# Back propagation finished in 0.003571748733520508 second(s)
# Total loss calculation finished in 0.0006659030914306641 second(s)
# Back propagation finished in 0.00386810302734375 second(s)
# Total loss calculation finished in 0.0008420944213867188 second(s)
# Back propagation finished in 0.0036323070526123047 second(s)
# Total loss calculation finished in 0.0007081031799316406 second(s)
# Back propagation finished in 0.0037567615509033203 second(s)
# Total loss calculation finished in 6.437301635742188e-05 second(s)
# Back propagation finished in 0.0037796497344970703 second(s)
# Total loss calculation finished in 0.0006444454193115234 second(s)
# Back propagation finished in 0.003815174102783203 second(s)
# Total loss calculation finished in 5.626678466796875e-05 second(s)
# Back propagation finished in 0.005501508712768555 second(s)
# Total loss calculation finished in 6.389617919921875e-05 second(s)
# Back propagation finished in 0.005415678024291992 second(s)
# Total loss calculation finished in 0.00041675567626953125 second(s)
# Back propagation finished in 0.005298137664794922 second(s)
# Total loss calculation finished in 5.745887756347656e-05 second(s)
# Back propagation finished in 0.005293130874633789 second(s)
# Total loss calculation finished in 6.270408630371094e-05 second(s)
# Back propagation finished in 0.005387783050537109 second(s)
# Total loss calculation finished in 0.00040602684020996094 second(s)
# Back propagation finished in 0.0038416385650634766 second(s)
# Total loss calculation finished in 0.00078582763671875 second(s)
# Back propagation finished in 0.003671407699584961 second(s)
# Total loss calculation finished in 0.0007643699645996094 second(s)
# Back propagation finished in 0.004541873931884766 second(s)
# Total loss calculation finished in 6.723403930664062e-05 second(s)
# Back propagation finished in 0.004439353942871094 second(s)
# Total loss calculation finished in 5.626678466796875e-05 second(s)
# Back propagation finished in 0.0037355422973632812 second(s)
# Total loss calculation finished in 4.1484832763671875e-05 second(s)
# Back propagation finished in 0.003674745559692383 second(s)
# Total loss calculation finished in 5.650520324707031e-05 second(s)
# Back propagation finished in 0.0036420822143554688 second(s)
# Total loss calculation finished in 5.555152893066406e-05 second(s)
# 100%|██████████| 5/5 [1:24:10<00:00, 1010.02s/it]
# Back propagation finished in 0.004791975021362305 second(s)
# Total loss calculation finished in 5.340576171875e-05 second(s)
# Back propagation finished in 0.004561901092529297 second(s)
# Total loss calculation finished in 6.127357482910156e-05 second(s)
# Back propagation finished in 0.004107236862182617 second(s)
# Total loss calculation finished in 4.506111145019531e-05 second(s)
# Back propagation finished in 0.004109621047973633 second(s)
# Total loss calculation finished in 3.266334533691406e-05 second(s)
# Back propagation finished in 0.00512385368347168 second(s)
# Total loss calculation finished in 3.790855407714844e-05 second(s)
# Back propagation finished in 0.004289150238037109 second(s)
# Total loss calculation finished in 3.8623809814453125e-05 second(s)
# Back propagation finished in 0.005165815353393555 second(s)
# Total loss calculation finished in 3.719329833984375e-05 second(s)
# Back propagation finished in 0.004687070846557617 second(s)
# Total loss calculation finished in 0.0004000663757324219 second(s)
# Back propagation finished in 0.005399942398071289 second(s)
# Total loss calculation finished in 0.0005764961242675781 second(s)
# Back propagation finished in 0.004047870635986328 second(s)
# Total loss calculation finished in 0.0006251335144042969 second(s)
# Back propagation finished in 0.0039119720458984375 second(s)
# Total loss calculation finished in 0.0006811618804931641 second(s)
# Back propagation finished in 0.003735065460205078 second(s)
# Total loss calculation finished in 0.0009131431579589844 second(s)
# Back propagation finished in 0.003683805465698242 second(s)
# Total loss calculation finished in 0.0008029937744140625 second(s)
# Back propagation finished in 0.0037589073181152344 second(s)
# Total loss calculation finished in 6.818771362304688e-05 second(s)
# Back propagation finished in 0.003853321075439453 second(s)
# Total loss calculation finished in 0.0007593631744384766 second(s)
# Back propagation finished in 0.0037848949432373047 second(s)
# Total loss calculation finished in 0.0007476806640625 second(s)
# Back propagation finished in 0.003704071044921875 second(s)
# Total loss calculation finished in 0.0006291866302490234 second(s)
# Back propagation finished in 0.003524303436279297 second(s)
# Total loss calculation finished in 0.0006814002990722656 second(s)
# Back propagation finished in 0.0036468505859375 second(s)
# Total loss calculation finished in 0.0007951259613037109 second(s)
# Back propagation finished in 0.003729104995727539 second(s)
# Total loss calculation finished in 0.0006680488586425781 second(s)
# Back propagation finished in 0.0037298202514648438 second(s)
# Total loss calculation finished in 0.0006899833679199219 second(s)
# Back propagation finished in 0.0037131309509277344 second(s)
# Total loss calculation finished in 0.0007512569427490234 second(s)
# Back propagation finished in 0.0037992000579833984 second(s)
# Total loss calculation finished in 0.0004832744598388672 second(s)
# Back propagation finished in 0.0036211013793945312 second(s)
# Total loss calculation finished in 0.0006613731384277344 second(s)
# Back propagation finished in 0.0036334991455078125 second(s)
# Total loss calculation finished in 0.0007004737854003906 second(s)
# Back propagation finished in 0.003633737564086914 second(s)
# Total loss calculation finished in 0.0007386207580566406 second(s)
# Back propagation finished in 0.003648996353149414 second(s)
# Total loss calculation finished in 0.000698089599609375 second(s)
# Back propagation finished in 0.0036699771881103516 second(s)
# Total loss calculation finished in 0.0005190372467041016 second(s)
#
# [1198235.5782006525, 3425216.6410468067, 3101060.390308101, 793819.1007214133, 129993.3218945255]
# Training of train_3000.txt finished in 5050.0944480896 second(s)

# %%
# learning curve (a posteriori)
import matplotlib.pyplot as plt

x = np.arange(0,NB_EPOCHS,1)

plt.xticks(np.arange(0,NB_EPOCHS+1,1)) # largir la distance de l'abscisse X
plt.plot(x, losses)

# see visdom module to vizualize learning curve during training

# %%
a = ['f', 'f', 'g']

neg_examples = []

for neg in a:
  neg_examples.append((neg, neg, 0))

# %%
neg_examples
# Out:
# [('f', 'f', 0), ('f', 'f', 0), ('g', 'g', 0)]
